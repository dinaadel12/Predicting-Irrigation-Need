# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import lightgbm as lgb
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import accuracy_score, classification_report

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout,BatchNormalization
from tensorflow.keras.regularizers import L1, L2
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.utils import to_categorical
from kerastuner.tuners import RandomSearch
import keras_tuner as kt
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_35380\1325775727.py:18: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv(r"C:\Users\Admin\Downloads\playground-series-s6e4\train.csv")
df_test = pd.read_csv(r"C:\Users\Admin\Downloads\playground-series-s6e4\test.csv")
df
# Out:
#             id Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0            0     Loamy     4.92          32.58            1.01
# 1            1      Clay     7.08          56.61            0.44
# 2            2      Clay     5.69          27.71            0.81
# 3            3     Sandy     5.65          13.32            1.33
# 4            4      Clay     7.96          59.14            0.38
# ...        ...       ...      ...            ...             ...
# 629995  629995      Clay     6.54          13.45            1.15
# 629996  629996      Clay     7.03          54.49            0.96
# 629997  629997      Clay     6.52          11.98            0.93
# 629998  629998      Clay     5.93          42.86            0.33
# 629999  629999     Loamy     7.02          35.36            1.19
#
#         Electrical_Conductivity  Temperature_C  Humidity  Rainfall_mm  \
# 0                          3.05          15.01     50.61       725.99
# 1                          2.00          22.92     67.86       985.66
# 2                          2.83          26.97     92.22      2201.70
# 3                          0.87          13.32     61.57      1357.33
# 4                          0.96          20.22     91.11      1538.20
# ...                         ...            ...       ...          ...
# 629995                     1.86          26.65     26.86      1041.33
# 629996                     2.35          36.99     88.00      1419.57
# 629997                     0.38          37.82     70.98        88.45
# 629998                     3.39          34.99     94.58      2433.92
# 629999                     0.46          26.92     64.33      1269.55
#
#         Sunlight_Hours  ...  Crop_Type Crop_Growth_Stage  Season  \
# 0                 5.90  ...  Sugarcane            Sowing    Zaid
# 1                 6.98  ...      Wheat        Vegetative  Kharif
# 2                 6.05  ...       Rice        Vegetative  Kharif
# 3                 9.12  ...      Wheat         Flowering  Kharif
# 4                 6.95  ...      Wheat            Sowing    Rabi
# ...                ...  ...        ...               ...     ...
# 629995           10.62  ...       Rice            Sowing  Kharif
# 629996            9.93  ...  Sugarcane        Vegetative  Kharif
# 629997            8.19  ...     Potato        Vegetative    Zaid
# 629998            9.88  ...  Sugarcane        Vegetative    Zaid
# 629999            7.91  ...      Maize           Harvest  Kharif
#
#        Irrigation_Type Water_Source Field_Area_hectare  Mulching_Used  \
# 0                 Drip    Rainwater               0.82             No
# 1              Rainfed        River               5.27            Yes
# 2            Sprinkler    Reservoir               8.24            Yes
# 3                Canal        River               8.32            Yes
# 4                Canal        River               7.37             No
# ...                ...          ...                ...            ...
# 629995       Sprinkler        River               4.35             No
# 629996            Drip  Groundwater              12.97            Yes
# 629997           Canal    Reservoir              13.58            Yes
# 629998       Sprinkler  Groundwater               0.79            Yes
# 629999            Drip    Reservoir               3.80             No
#
#        Previous_Irrigation_mm   Region Irrigation_Need
# 0                      112.16     East             Low
# 1                       47.16    South             Low
# 2                      110.38    North             Low
# 3                       53.85    South          Medium
# 4                       93.19    South             Low
# ...                       ...      ...             ...
# 629995                 118.36    South          Medium
# 629996                  40.75  Central          Medium
# 629997                   2.62    South            High
# 629998                  90.00     East             Low
# 629999                 112.93     West             Low
#
# [630000 rows x 21 columns]

# %%
df.columns
df_test.columns
# Out:
# Index(['id', 'Soil_Type', 'Soil_pH', 'Soil_Moisture', 'Organic_Carbon',
#        'Electrical_Conductivity', 'Temperature_C', 'Humidity', 'Rainfall_mm',
#        'Sunlight_Hours', 'Wind_Speed_kmh', 'Crop_Type', 'Crop_Growth_Stage',
#        'Season', 'Irrigation_Type', 'Water_Source', 'Field_Area_hectare',
#        'Mulching_Used', 'Previous_Irrigation_mm', 'Region'],
#       dtype='object')

# %% [markdown]
# # explortory data

# %%
df.drop("id",axis=1 ,inplace=True)
sub = df_test[['id']]
df_test.drop("id",axis=1 ,inplace=True)

# %%
df["Irrigation_Need"].unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630000 entries, 0 to 629999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Soil_Type                630000 non-null  object
#  1   Soil_pH                  630000 non-null  float64
#  2   Soil_Moisture            630000 non-null  float64
#  3   Organic_Carbon           630000 non-null  float64
#  4   Electrical_Conductivity  630000 non-null  float64
#  5   Temperature_C            630000 non-null  float64
#  6   Humidity                 630000 non-null  float64
#  7   Rainfall_mm              630000 non-null  float64
#  8   Sunlight_Hours           630000 non-null  float64
#  9   Wind_Speed_kmh           630000 non-null  float64
#  10  Crop_Type                630000 non-null  object
#  11  Crop_Growth_Stage        630000 non-null  object
#  12  Season                   630000 non-null  object
#  13  Irrigation_Type          630000 non-null  object
#  14  Water_Source             630000 non-null  object
#  15  Field_Area_hectare       630000 non-null  float64
#  16  Mulching_Used            630000 non-null  object
#  17  Previous_Irrigation_mm   630000 non-null  float64
#  18  Region                   630000 non-null  object
#  19  Irrigation_Need          630000 non-null  object
# dtypes: float64(11), object(9)
# memory usage: 96.1+ MB

# %%
df.isna().sum()
df_test.isna().sum()
# Out:
# Soil_Type                  0
# Soil_pH                    0
# Soil_Moisture              0
# Organic_Carbon             0
# Electrical_Conductivity    0
# Temperature_C              0
# Humidity                   0
# Rainfall_mm                0
# Sunlight_Hours             0
# Wind_Speed_kmh             0
# Crop_Type                  0
# Crop_Growth_Stage          0
# Season                     0
# Irrigation_Type            0
# Water_Source               0
# Field_Area_hectare         0
# Mulching_Used              0
# Previous_Irrigation_mm     0
# Region                     0
# dtype: int64

# %%
df_test.isna().sum()
# Out:
# Soil_Type                  0
# Soil_pH                    0
# Soil_Moisture              0
# Organic_Carbon             0
# Electrical_Conductivity    0
# Temperature_C              0
# Humidity                   0
# Rainfall_mm                0
# Sunlight_Hours             0
# Wind_Speed_kmh             0
# Crop_Type                  0
# Crop_Growth_Stage          0
# Season                     0
# Irrigation_Type            0
# Water_Source               0
# Field_Area_hectare         0
# Mulching_Used              0
# Previous_Irrigation_mm     0
# Region                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_test.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe().T
# Out:
#                             count         mean         std    min       25%  \
# Soil_pH                  630000.0     6.482497    0.922504   4.80    5.6900
# Soil_Moisture            630000.0    37.304482   16.377082   8.00   23.3400
# Organic_Carbon           630000.0     0.922858    0.365808   0.30    0.6100
# Electrical_Conductivity  630000.0     1.744605    0.952321   0.10    0.9300
# Temperature_C            630000.0    26.998166    8.623621  12.00   19.5175
# Humidity                 630000.0    61.563180   19.708152  25.00   45.3900
# Rainfall_mm              630000.0  1462.207566  612.989738   0.38  954.5700
# Sunlight_Hours           630000.0     7.513382    1.999322   4.00    5.7600
# Wind_Speed_kmh           630000.0    10.375394    5.689458   0.50    5.2800
# Field_Area_hectare       630000.0     7.517745    4.218124   0.30    3.8800
# Previous_Irrigation_mm   630000.0    62.318177   34.246939   0.02   33.1400
#
#                              50%      75%      max
# Soil_pH                     6.44     7.27     8.20
# Soil_Moisture              37.75    51.27    64.99
# Organic_Carbon              0.91     1.22     1.60
# Electrical_Conductivity     1.74     2.58     3.50
# Temperature_C              26.96    34.54    42.00
# Humidity                   61.65    79.12    94.99
# Rainfall_mm              1467.16  2054.28  2499.69
# Sunlight_Hours              7.58     9.25    11.00
# Wind_Speed_kmh             10.48    15.43    20.00
# Field_Area_hectare          7.38    11.14    15.00
# Previous_Irrigation_mm     61.15    92.69   119.99

# %%
numeric_cols = df.select_dtypes(include='number').columns
outliers_dict = {}

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)][col]
    outliers_dict[col] = outliers.values
for col, values in outliers_dict.items():
    print(f"Outliers in {col}: {values}\n")
# Out:
# Outliers in Soil_pH: []
#
# Outliers in Soil_Moisture: []
#
# Outliers in Organic_Carbon: []
#
# Outliers in Electrical_Conductivity: []
#
# Outliers in Temperature_C: []
#
# Outliers in Humidity: []
#
# Outliers in Rainfall_mm: []
#
# Outliers in Sunlight_Hours: []
#
# Outliers in Wind_Speed_kmh: []
#
# Outliers in Field_Area_hectare: []
#
# Outliers in Previous_Irrigation_mm: []

# %%
numeric_cols = df.select_dtypes(include='number').columns
outliers_dict = {}

for col in numeric_cols:
    Q1 = df_test[col].quantile(0.25)
    Q3 = df_test[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df_test[(df_test[col] < lower_bound) | (df_test[col] > upper_bound)][col]
    outliers_dict[col] = outliers.values
for col, values in outliers_dict.items():
    print(f"Outliers in {col}: {values}\n")
# Out:
# Outliers in Soil_pH: []
#
# Outliers in Soil_Moisture: []
#
# Outliers in Organic_Carbon: []
#
# Outliers in Electrical_Conductivity: []
#
# Outliers in Temperature_C: []
#
# Outliers in Humidity: []
#
# Outliers in Rainfall_mm: []
#
# Outliers in Sunlight_Hours: []
#
# Outliers in Wind_Speed_kmh: []
#
# Outliers in Field_Area_hectare: []
#
# Outliers in Previous_Irrigation_mm: []

# %% [markdown]
# # Feature Engineering

# %%
#convert columns from kmh to m/s

df['Wind_Speed_m/s'] = df['Wind_Speed_kmh'] / 3.6

df_test['Wind_Speed_m/s'] = df_test['Wind_Speed_kmh'] / 3.6

# %%
# function used to determine It is an index that determines the relationship between temperature, sunshine hours, humidity, and wind speed.
#  It illustrates all the atmospheric influences that can affect the data. 
# Because the relationship between temperature and humidity is inverse—the higher the temperature, the lower the humidity—the larger the index, and therefore the greater the amount of water required.
def calculate_ET_proxy(r):
    temperature_term = r['Temperature_C'] + 17.8
    sunlight_term = r['Sunlight_Hours']
    
 
    adjustment = (100 - r['Humidity']) / 100 * (1 + r['Wind_Speed_m/s']/10)
    
    ET_proxy = temperature_term * sunlight_term * adjustment
    return ET_proxy


df['ET_Proxy'] = df.apply(calculate_ET_proxy, axis=1)
#if the temperature is higher and the humidity is lower, the et proxy index will be large, so the plant will need more water.
#  Therefore, the lower the humidity, the faster the wind will blow.
df_test['ET_Proxy'] = df_test.apply(calculate_ET_proxy, axis=1)

df_test['ET_Proxy'] = df_test.apply(calculate_ET_proxy, axis=1)

# %%
#The vapour in the original law describes the relationship between the pressure of water molecules in the air (which can be replaced in our data with atmospheric humidity and temperature).
#  This means that as the temperature increases, the humidity decreases, and therefore more irrigation is needed.
df['vapour_proxy'] = df['Temperature_C'] * (1 - (df['Humidity'] / 100))
df_test['vapour_proxy'] = df_test['Temperature_C'] * (1 - (df_test['Humidity'] / 100))

# %%
# Factors affecting evaporation
df['factors_vapour'] = (
    df['Temperature_C'] *
    df['Sunlight_Hours'] *
    df['Wind_Speed_m/s'] /
    (df['Humidity'] + 1)
)


df_test['factors_vapour'] = (
    df_test['Temperature_C'] *
    df_test['Sunlight_Hours'] *
    df_test['Wind_Speed_m/s'] /
    (df_test['Humidity'] + 1)
)

# %%
#It illustrates the relationship between the amount of rainfall and the previous irrigation of the land,
#  and we also subtract the index of the amount of transpiration that occurs as a result of weather factors.

df['Water_balance'] = df['Rainfall_mm'] + df['Previous_Irrigation_mm'] - df['ET_Proxy']

df_test['Water_balance'] = df_test['Rainfall_mm'] + df_test['Previous_Irrigation_mm'] - df_test['ET_Proxy']

# %%
#It explains the relationship between the amount of rainfall and soil moisture; the relationship between them is direct.

df['SM_Rain_interaction'] = df['Soil_Moisture'] * df['Rainfall_mm']

df_test['SM_Rain_interaction'] = df_test['Soil_Moisture'] * df_test['Rainfall_mm']

# %%
# It explains the relationship between temperature and soil moisture, and that the relationship between them is inverse.
df['SM_Temp_ratio'] = df['Soil_Moisture'] / (df['Temperature_C'] + 1)

df_test['SM_Temp_ratio'] = df_test['Soil_Moisture'] / (df_test['Temperature_C'] + 1)

# %%
#This explains the relationship between adding carbonaceous material and soil moisture. 
# Carbon indicates soil fertility and helps it retain water better,
#  meaning that increasing this material reduces the need for irrigation.

df['SM_Organic_interaction'] = df['Soil_Moisture'] * df['Organic_Carbon']

df_test['SM_Organic_interaction'] = df_test['Soil_Moisture'] * df_test['Organic_Carbon']

# %%
df['Rainfall_log'] = np.log(df['Rainfall_mm'] + 1)
df['ET_proxy_log'] = np.log(df['ET_Proxy'] + 1)

# %%
df_test['Rainfall_log'] = np.log(df_test['Rainfall_mm'] + 1)
df_test['ET_proxy_log'] = np.log(df_test['ET_Proxy'] + 1)

# %%
df['Field_Efficiency'] = df["Previous_Irrigation_mm"] +df["Field_Area_hectare"]

# %%
df_test['Field_Efficiency'] = df_test["Previous_Irrigation_mm"] +df_test["Field_Area_hectare"]

# %%
df['Soil_retention_proxy'] = (df['Soil_Moisture'] * (1 + df['Organic_Carbon']) / (df['Soil_pH'] + 1))

# %%
df_test['Soil_retention_proxy'] = (df_test['Soil_Moisture'] * (1 + df_test['Organic_Carbon']) / (df_test['Soil_pH'] + 1))

# %%
df['Clay_like_behavior'] = df['Soil_Moisture'] * df['Electrical_Conductivity']

# %%
df_test['Clay_like_behavior'] = df_test['Soil_Moisture'] * df_test['Electrical_Conductivity']

# %%
region_mean_et = df.groupby("Region")["ET_Proxy"].mean()
df["Region_mean_ET"] = df["Region"].map(region_mean_et)

# %%
region_mean_et = df_test.groupby("Region")["ET_Proxy"].mean()
df_test["Region_mean_ET"] = df_test["Region"].map(region_mean_et)

# %%
df["Regional_demand_factor"] = df["ET_Proxy"] / (df["Region_mean_ET"] + 1e-6)

# %%
df_test["Regional_demand_factor"] = df_test["ET_Proxy"] / (df_test["Region_mean_ET"] + 1e-6)

# %%
mapp= {"Low":0, "Medium":1, "High":2}
df['Irrigation_Need'] = df['Irrigation_Need'].map(mapp)

# %% [markdown]
# # EDA

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])


corr = numeric_df.corr()


plt.figure(figsize=(20, 15))   
sns.heatmap(corr, 
            annot=True,       
            cmap='coolwarm',    
            vmin=-1, 
            vmax=1,
            fmt='.2f')         

plt.title('Correlation Heatmap - Soil & Irrigation Data', fontsize=14)
plt.xticks(rotation=45, ha='right')   
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
sns.lineplot(x='Soil_Type',y='Soil_Moisture',data=df)
# Out:
# <Axes: xlabel='Soil_Type', ylabel='Soil_Moisture'>

# %%
sns.histplot(df["ET_Proxy"],kde=True)
# Out:
# <Axes: xlabel='ET_Proxy', ylabel='Count'>

# %%
sns.histplot(df["ET_proxy_log"],kde=True)
# Out:
# <Axes: xlabel='ET_proxy_log', ylabel='Count'>

# %%
num_cols = df.select_dtypes(include='number').columns

plt.figure(figsize=(15,10))
for i, col in enumerate(num_cols[:9]):
 plt.subplot(3,3,i+1)
 sns.histplot(df[col], kde=True)
 plt.title(col)

plt.tight_layout()
plt.show()

# %%
sns.countplot(x="Irrigation_Need", data=df)
plt.title("Target Distribution")
plt.show()

print(df["Irrigation_Need"].value_counts())
# Out:
# Irrigation_Need
# 0    369917
# 1    239074
# 2     21009
# Name: count, dtype: int64

# %% [markdown]
# # Train Test Split

# %%
x= df.drop(["Irrigation_Need"],axis=1)
y=df["Irrigation_Need"]
y = to_categorical(y)
x_train ,x_test ,y_train ,y_test =train_test_split(x,y,train_size=0.8,random_state=42)

# %% [markdown]
# # Data Preprocessing

# %%
cat_cols = list(x_train.select_dtypes(include=["object"]).columns)
encoder = OrdinalEncoder()
x_train[cat_cols] = encoder.fit_transform(x_train[cat_cols])
x_test[cat_cols] = encoder.transform(x_test[cat_cols])

# %% [markdown]
# # scale Data

# %%
scaler = StandardScaler()
x_train =scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# # Data Modeling

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(x_train.shape[1],)),
    Dropout(0.2),
    Dense(96, activation='tanh' ),
    Dropout(0.3),
    Dense(64, activation='tanh'),
    #Dropout(.1),
    Dense(3, activation='softmax')
])

model.summary()
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         4,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 96)             │        12,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 96)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,267 (90.89 KB)
#  Trainable params: 23,267 (90.89 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss = 'categorical_crossentropy', metrics = ['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=5)

model.fit(x_train, y_train, epochs=150,
         validation_split=0.1, batch_size=360, 
          callbacks=[early_stopping])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7244 - loss: 0.5883 - val_accuracy: 0.7710 - val_loss: 0.4788
# Epoch 2/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7944 - loss: 0.4493 - val_accuracy: 0.8770 - val_loss: 0.3022
# Epoch 3/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8673 - loss: 0.3194 - val_accuracy: 0.9089 - val_loss: 0.2334
# Epoch 4/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8894 - loss: 0.2726 - val_accuracy: 0.9218 - val_loss: 0.2055
# Epoch 5/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9046 - loss: 0.2396 - val_accuracy: 0.9330 - val_loss: 0.1814
# Epoch 6/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9172 - loss: 0.2115 - val_accuracy: 0.9407 - val_loss: 0.1619
# Epoch 7/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9269 - loss: 0.1893 - val_accuracy: 0.9444 - val_loss: 0.1503
# Epoch 8/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9328 - loss: 0.1750 - val_accuracy: 0.9471 - val_loss: 0.1433
# Epoch 9/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9376 - loss: 0.1640 - val_accuracy: 0.9501 - val_loss: 0.1365
# Epoch 10/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9416 - loss: 0.1556 - val_accuracy: 0.9526 - val_loss: 0.1316
# Epoch 11/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9446 - loss: 0.1483 - val_accuracy: 0.9548 - val_loss: 0.1268
# Epoch 12/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9478 - loss: 0.1422 - val_accuracy: 0.9582 - val_loss: 0.1214
# Epoch 13/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9502 - loss: 0.1360 - val_accuracy: 0.9609 - val_loss: 0.1153
# Epoch 14/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9542 - loss: 0.1291 - val_accuracy: 0.9648 - val_loss: 0.1088
# Epoch 15/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9574 - loss: 0.1231 - val_accuracy: 0.9680 - val_loss: 0.1027
# Epoch 16/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9604 - loss: 0.1169 - val_accuracy: 0.9704 - val_loss: 0.0978
# Epoch 17/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9627 - loss: 0.1121 - val_accuracy: 0.9725 - val_loss: 0.0938
# Epoch 18/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9653 - loss: 0.1071 - val_accuracy: 0.9739 - val_loss: 0.0903
# Epoch 19/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9667 - loss: 0.1039 - val_accuracy: 0.9751 - val_loss: 0.0878
# Epoch 20/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9683 - loss: 0.1005 - val_accuracy: 0.9763 - val_loss: 0.0852
# Epoch 21/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9697 - loss: 0.0973 - val_accuracy: 0.9770 - val_loss: 0.0839
# Epoch 22/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9707 - loss: 0.0948 - val_accuracy: 0.9781 - val_loss: 0.0816
# Epoch 23/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9717 - loss: 0.0926 - val_accuracy: 0.9789 - val_loss: 0.0798
# Epoch 24/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9727 - loss: 0.0907 - val_accuracy: 0.9787 - val_loss: 0.0787
# Epoch 25/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9735 - loss: 0.0889 - val_accuracy: 0.9794 - val_loss: 0.0775
# Epoch 26/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9744 - loss: 0.0870 - val_accuracy: 0.9797 - val_loss: 0.0769
# Epoch 27/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9750 - loss: 0.0856 - val_accuracy: 0.9801 - val_loss: 0.0756
# Epoch 28/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9756 - loss: 0.0844 - val_accuracy: 0.9802 - val_loss: 0.0752
# Epoch 29/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9759 - loss: 0.0830 - val_accuracy: 0.9807 - val_loss: 0.0742
# Epoch 30/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9766 - loss: 0.0822 - val_accuracy: 0.9806 - val_loss: 0.0733
# Epoch 31/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9769 - loss: 0.0812 - val_accuracy: 0.9812 - val_loss: 0.0728
# Epoch 32/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9772 - loss: 0.0802 - val_accuracy: 0.9811 - val_loss: 0.0726
# Epoch 33/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9776 - loss: 0.0794 - val_accuracy: 0.9811 - val_loss: 0.0720
# Epoch 34/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9781 - loss: 0.0784 - val_accuracy: 0.9814 - val_loss: 0.0714
# Epoch 35/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9784 - loss: 0.0778 - val_accuracy: 0.9814 - val_loss: 0.0713
# Epoch 36/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9785 - loss: 0.0771 - val_accuracy: 0.9818 - val_loss: 0.0706
# Epoch 37/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9788 - loss: 0.0767 - val_accuracy: 0.9814 - val_loss: 0.0705
# Epoch 38/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9790 - loss: 0.0759 - val_accuracy: 0.9819 - val_loss: 0.0700
# Epoch 39/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9791 - loss: 0.0756 - val_accuracy: 0.9819 - val_loss: 0.0700
# Epoch 40/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9794 - loss: 0.0749 - val_accuracy: 0.9820 - val_loss: 0.0694
# Epoch 41/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9798 - loss: 0.0742 - val_accuracy: 0.9820 - val_loss: 0.0692
# Epoch 42/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9797 - loss: 0.0743 - val_accuracy: 0.9821 - val_loss: 0.0689
# Epoch 43/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9799 - loss: 0.0737 - val_accuracy: 0.9823 - val_loss: 0.0686
# Epoch 44/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9801 - loss: 0.0735 - val_accuracy: 0.9822 - val_loss: 0.0684
# Epoch 45/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9802 - loss: 0.0729 - val_accuracy: 0.9826 - val_loss: 0.0682
# Epoch 46/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9805 - loss: 0.0727 - val_accuracy: 0.9827 - val_loss: 0.0678
# Epoch 47/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9804 - loss: 0.0721 - val_accuracy: 0.9827 - val_loss: 0.0674
# Epoch 48/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9806 - loss: 0.0719 - val_accuracy: 0.9828 - val_loss: 0.0675
# Epoch 49/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9808 - loss: 0.0717 - val_accuracy: 0.9824 - val_loss: 0.0674
# Epoch 50/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9808 - loss: 0.0716 - val_accuracy: 0.9824 - val_loss: 0.0675
# Epoch 51/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9811 - loss: 0.0711 - val_accuracy: 0.9829 - val_loss: 0.0669
# Epoch 52/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9809 - loss: 0.0712 - val_accuracy: 0.9828 - val_loss: 0.0672
# Epoch 53/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9812 - loss: 0.0707 - val_accuracy: 0.9828 - val_loss: 0.0668
# Epoch 54/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9813 - loss: 0.0704 - val_accuracy: 0.9824 - val_loss: 0.0669
# Epoch 55/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9815 - loss: 0.0699 - val_accuracy: 0.9830 - val_loss: 0.0667
# Epoch 56/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9814 - loss: 0.0699 - val_accuracy: 0.9828 - val_loss: 0.0667
# Epoch 57/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9814 - loss: 0.0699 - val_accuracy: 0.9830 - val_loss: 0.0663
# Epoch 58/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9817 - loss: 0.0693 - val_accuracy: 0.9829 - val_loss: 0.0667
# Epoch 59/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9818 - loss: 0.0693 - val_accuracy: 0.9829 - val_loss: 0.0662
# Epoch 60/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9816 - loss: 0.0692 - val_accuracy: 0.9832 - val_loss: 0.0661
# Epoch 61/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9817 - loss: 0.0690 - val_accuracy: 0.9832 - val_loss: 0.0658
# Epoch 62/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9819 - loss: 0.0686 - val_accuracy: 0.9830 - val_loss: 0.0659
# Epoch 63/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9820 - loss: 0.0686 - val_accuracy: 0.9830 - val_loss: 0.0660
# Epoch 64/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9820 - loss: 0.0684 - val_accuracy: 0.9833 - val_loss: 0.0655
# Epoch 65/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9820 - loss: 0.0683 - val_accuracy: 0.9834 - val_loss: 0.0656
# Epoch 66/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9824 - loss: 0.0677 - val_accuracy: 0.9835 - val_loss: 0.0655
# Epoch 67/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9823 - loss: 0.0678 - val_accuracy: 0.9832 - val_loss: 0.0657
# Epoch 68/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9822 - loss: 0.0677 - val_accuracy: 0.9832 - val_loss: 0.0655
# Epoch 69/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9823 - loss: 0.0679 - val_accuracy: 0.9833 - val_loss: 0.0654
# Epoch 70/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9824 - loss: 0.0675 - val_accuracy: 0.9834 - val_loss: 0.0658
# Epoch 71/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9826 - loss: 0.0671 - val_accuracy: 0.9834 - val_loss: 0.0652
# Epoch 72/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9824 - loss: 0.0674 - val_accuracy: 0.9834 - val_loss: 0.0652
# Epoch 73/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9824 - loss: 0.0674 - val_accuracy: 0.9835 - val_loss: 0.0649
# Epoch 74/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9825 - loss: 0.0672 - val_accuracy: 0.9834 - val_loss: 0.0651
# Epoch 75/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9826 - loss: 0.0670 - val_accuracy: 0.9837 - val_loss: 0.0649
# Epoch 76/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9826 - loss: 0.0670 - val_accuracy: 0.9834 - val_loss: 0.0649
# Epoch 77/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9827 - loss: 0.0667 - val_accuracy: 0.9835 - val_loss: 0.0648
# Epoch 78/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9827 - loss: 0.0666 - val_accuracy: 0.9834 - val_loss: 0.0650
# Epoch 79/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9827 - loss: 0.0667 - val_accuracy: 0.9835 - val_loss: 0.0648
# Epoch 80/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9827 - loss: 0.0665 - val_accuracy: 0.9837 - val_loss: 0.0646
# Epoch 81/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9829 - loss: 0.0660 - val_accuracy: 0.9833 - val_loss: 0.0651
# Epoch 82/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9828 - loss: 0.0665 - val_accuracy: 0.9835 - val_loss: 0.0646
# Epoch 83/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9829 - loss: 0.0662 - val_accuracy: 0.9833 - val_loss: 0.0651
# Epoch 84/150
#  502/1260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9830 - loss: 0.0651

# %%
model.evaluate(x_test,y_test)
# Out:
# 3938/3938 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.9836 - loss: 0.0634
# [0.063438780605793, 0.9836269617080688]

# %%
def build_model(hp):
    model = Sequential()
    model.add(Dense(
        units=hp.Int('units_1', min_value=64, max_value=256, step=64),
        activation='relu',
        input_shape=(x_train.shape[1],)
    ))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float('dropout_1', 0.2, 0.5, step=0.1)))
    
    model.add(Dense(
        units=hp.Int('units_2', min_value=32, max_value=128, step=32),
        activation='relu'
    ))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float('dropout_2', 0.2, 0.5, step=0.1)))
    
    model.add(Dense(
        units=hp.Int('units_3', min_value=16, max_value=64, step=16),
        activation='tanh'
    ))
    model.add(Dense(3, activation='softmax'))
    
    lr = hp.Choice('learning_rate', values=[1e-2, 1e-3, 5e-4, 1e-4])
    
    model.compile(
        optimizer=Adam(learning_rate=lr),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,
    executions_per_trial=1,
    directory='tuner_dir',
    project_name='irrigation_dnn21'
)

tuner.search(
    x_train, y_train,
    validation_data=(x_test, y_test),
    epochs=30,
    batch_size=256,
    verbose=1
)

best_model = tuner.get_best_models(num_models=1)[0]

best_hp = tuner.get_best_hyperparameters(1)[0]

print("\n Best Hyperparameters:")
print(best_hp.values)

loss, acc = best_model.evaluate(x_test, y_test)
print(f"\n Best Tuned Accuracy: {acc:.4f}")
# Out:
# Trial 10 Complete [00h 04m 44s]
# val_accuracy: 0.9797222018241882
#
# Best val_accuracy So Far: 0.9828571677207947
# Total elapsed time: 00h 48m 06s
# C:\Users\Admin\AppData\Roaming\Python\Python313\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 26 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
#  Best Hyperparameters:
# {'units_1': 192, 'dropout_1': 0.30000000000000004, 'units_2': 128, 'dropout_2': 0.2, 'units_3': 32, 'learning_rate': 0.0001}
# 3938/3938 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.9829 - loss: 0.0665
#
#  Best Tuned Accuracy: 0.9829

# %%
weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(df['Irrigation_Need']),
    y=df['Irrigation_Need']
)

class_weights_dict = dict(enumerate(weights))

model.fit(x_train, y_train, 
          epochs=150, 
          batch_size=360,
          class_weight=class_weights_dict, 
          validation_split=0.1,
          callbacks=[early_stopping])
model.evaluate(x_test,y_test)
# Out:
# Epoch 1/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9790 - loss: 0.1056 - val_accuracy: 0.9811 - val_loss: 0.0836
# Epoch 2/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9789 - loss: 0.1032 - val_accuracy: 0.9804 - val_loss: 0.0836
# Epoch 3/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9790 - loss: 0.1021 - val_accuracy: 0.9807 - val_loss: 0.0810
# Epoch 4/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9787 - loss: 0.1015 - val_accuracy: 0.9807 - val_loss: 0.0815
# Epoch 5/150
# 1260/1260 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9791 - loss: 0.1015 - val_accuracy: 0.9808 - val_loss: 0.0824
# 3938/3938 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.9813 - loss: 0.0799
# [0.0799093246459961, 0.981333315372467]

# %%
y_train_labels = np.argmax(y_train, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

print("Training XGBoost...")
xgb_model = xgb.XGBClassifier(
    n_estimators=500,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    use_label_encoder=False,
    eval_metric='mlogloss'
)
xgb_model.fit(x_train, y_train_labels)
xgb_preds = xgb_model.predict(x_test)
xgb_acc = accuracy_score(y_test_labels, xgb_preds)

print("Training LightGBM...")
lgb_model = lgb.LGBMClassifier(
    n_estimators=500,
    learning_rate=0.05,
    num_leaves=31,
    random_state=42,
    verbose=-1
)
lgb_model.fit(x_train, y_train_labels)
lgb_preds = lgb_model.predict(x_test)
lgb_acc = accuracy_score(y_test_labels, lgb_preds)
 

print("\n" + "="*30)
print("Final Comparison (Accuracy):")
print(f"Deep Learning Model: {0.9831:.4f}")
print(f"XGBoost Model:       {xgb_acc:.4f}")
print(f"LightGBM Model:      {lgb_acc:.4f}")
print("="*30)


print("\nXGBoost Detailed Report:")
print(classification_report(y_test_labels, xgb_preds, target_names=["Low", "Medium", "High"]))
# Out:
# Training XGBoost...
# C:\Users\Admin\AppData\Roaming\Python\Python313\site-packages\xgboost\training.py:200: UserWarning: [11:56:50] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Training LightGBM...
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# ==============================
# Final Comparison (Accuracy):
# Deep Learning Model: 0.9831
# XGBoost Model:       0.9847
# LightGBM Model:      0.9846
# ==============================
#
# XGBoost Detailed Report:
#               precision    recall  f1-score   support
#
#          Low       0.99      1.00      0.99     73737
#       Medium       0.98      0.98      0.98     48014
#         High       0.97      0.91      0.94      4249
#
#     accuracy                           0.98    126000
#    macro avg       0.98      0.96      0.97    126000
# weighted avg       0.98      0.98      0.98    126000

# %%
importance = pd.DataFrame({
    "feature": x_train.columns,
    "importance": model.feature_importances_
}).sort_values(by="importance", ascending=False)

# %% [markdown]
# ## Saving Model

# %%
import pickle

with open("encoder.pkl" ,"wb") as f:
    pickle.dumps(encoder)

with open("scaler.pkl" ,"wb") as f:
    pickle.dumps(scaler)

# %%
model.save("model21.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # Data Preprocessing of test data

# %%
df_test[cat_cols] = encoder.transform(df_test[cat_cols])

# %% [markdown]
# # scale Data

# %%
df_test=scaler.transform(df_test)

# %% [markdown]
# ## predict test

# %%
y_pred=model.predict(df_test)
# Out:
# 8438/8438 ━━━━━━━━━━━━━━━━━━━━ 6s 732us/step

# %% [markdown]
# # submit

# %%
reverse= {0:"Low", 1:"Medium", 2:"High"}

preds = []
for pred in y_pred:
    arg = np.argmax(pred)
    output = reverse[arg]

    preds.append(output)

# %%
sub['Irrigation_Need'] = preds

# %%
sub.to_csv("sub21.csv", index=False)
